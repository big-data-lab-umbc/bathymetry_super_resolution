# %% [markdown]
# #Transfer tif to png (done in local, need to be updated in jupyter notebook)
# import cv2
# import os
# import numpy as np
#
# path = os.getcwd()
# print(path)
#
# imagesDirectory= os.path.join(path,"sr_data")  # tif image directory
# distDirectory = os.path.dirname(imagesDirectory)
# distDirectory = os.path.join(distDirectory, "sr_png")# save directory
#
# for imageName in os.listdir(imagesDirectory):
#     imagePath = os.path.join(imagesDirectory, imageName)
#     image = cv2.imread(imagePath)# open tif image
#     img = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
#     distImagePath = os.path.join(distDirectory, imageName[:-4]+'.png')# save imgaes
#     cv2.imwrite(distImagePath,img)# write imgaes

# %%
#Traninig

# %%
import argparse
import os
import numpy as np
import math
import itertools
import sys

import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid

from torch.utils.data import DataLoader
from torch.autograd import Variable

from models import *
from datasets import *

import torch.nn as nn
import torch.nn.functional as F
import torch

os.makedirs("images", exist_ok=True)
os.makedirs("saved_models", exist_ok=True)


epoch=0
n_epochs=200
#dataset_name="img_hr"
batch_size=4
lr=0.0002
b1=0.5
b2=0.999
decay_epoch=200
n_cpu=8
hr_height=512
hr_width=512
channels=1
sample_interval=50
checkpoint_interval=50

cuda = torch.cuda.is_available()

hr_shape = (hr_height, hr_width)

# Initialize generator and discriminator
generator = GeneratorResNet(in_channels=channels, out_channels=channels)
discriminator = Discriminator(input_shape=(channels, *hr_shape))
feature_extractor = FeatureExtractor()

# Set feature extractor to inference mode
feature_extractor.eval()

# Losses
criterion_GAN = torch.nn.MSELoss()
criterion_content = torch.nn.L1Loss()

if cuda:
    generator = generator.cuda()
    discriminator = discriminator.cuda()
    feature_extractor = feature_extractor.cuda()
    criterion_GAN = criterion_GAN.cuda()
    criterion_content = criterion_content.cuda()

if epoch != 0:
    # Load pretrained models
    generator.load_state_dict(torch.load("saved_models/generator_%d.pth"))
    discriminator.load_state_dict(torch.load("saved_models/discriminator_%d.pth"))

# Optimizers
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))

Tensor = torch.cuda.FloatTensor if cuda else torch.Tensor

dataloader = DataLoader(
    #ImageDataset("../../data/%s" % opt.dataset_name, hr_shape=hr_shape),
    ImageDataset("../../data/", hr_shape=hr_shape),
    batch_size=batch_size,
    shuffle=True,
    num_workers=n_cpu,
)

# ----------
#  Training
# ----------

Dloss=[]
Gloss=[]

for epoch in range(epoch, n_epochs):
    for i, imgs in enumerate(dataloader):

        # Configure model input
        imgs_lr = Variable(imgs["lr"].type(Tensor))
        imgs_hr = Variable(imgs["hr"].type(Tensor))
    ##    print(imgs_hr)

        # Adversarial ground truths
        valid = Variable(Tensor(np.ones((imgs_lr.size(0), *discriminator.output_shape))), requires_grad=False)
        fake = Variable(Tensor(np.zeros((imgs_lr.size(0), *discriminator.output_shape))), requires_grad=False)

        # ------------------
        #  Train Generators
        # ------------------

        optimizer_G.zero_grad()

        # Generate a high resolution image from low resolution input
        gen_hr = generator(imgs_lr)
        #print(gen_hr)

        # Adversarial loss
        loss_GAN = criterion_GAN(discriminator(gen_hr), valid)

        # Content loss
    #    gen_features = feature_extractor(gen_hr)
        gen_features = feature_extractor(torch.cat((gen_hr,gen_hr,gen_hr),1))
        
    #    real_features = feature_extractor(imgs_hr)
        real_features = feature_extractor(torch.cat((imgs_hr,imgs_hr,imgs_hr),1))
        
    #    loss_content = criterion_content(gen_features, real_features.detach())
        loss_content = criterion_content(gen_hr, imgs_hr.detach()) + criterion_content(gen_features, real_features.detach())
    #    loss_content = criterion_content(gen_hr, imgs_hr.detach())

        # Total loss
        loss_G = loss_content + 1e-5 * loss_GAN  
##        loss_G = loss_content    #No GAN loss

        loss_G.backward()
        optimizer_G.step()

        # ---------------------
        #  Train Discriminator
        # ---------------------

        optimizer_D.zero_grad()

        # Loss of real and fake images
        loss_real = criterion_GAN(discriminator(imgs_hr), valid)
        loss_fake = criterion_GAN(discriminator(gen_hr.detach()), fake)

        # Total loss
        loss_D = (loss_real + loss_fake) / 2

        loss_D.backward()
        optimizer_D.step()

        # --------------
        #  Log Progress
        # --------------

        sys.stdout.write(
            "[Epoch %d/%d] [Batch %d/%d] [D loss: %f] [G loss: %f]\n"
            % (epoch+1, n_epochs, i+1, len(dataloader), loss_D.item(), loss_G.item())
        )

        Dloss.append(loss_D.item())
        Gloss.append(loss_G.item())

        batches_done = epoch * len(dataloader) + i
        if (batches_done+1) % sample_interval == 0:
            # Save image grid with upsampled inputs and SRGAN outputs
            imgs_lr = nn.functional.interpolate(imgs_lr, scale_factor=4)
            gen_hr = make_grid(gen_hr, nrow=1, normalize=True)
            imgs_lr = make_grid(imgs_lr, nrow=1, normalize=True)
            imgs_hr = make_grid(imgs_hr, nrow=1,normalize=True)
            img_grid = torch.cat((imgs_lr, gen_hr, imgs_hr), -1)
            
            save_image(imgs_hr, "images/tif_epoch200_data200_GAN0.1_ep4/hr%d.png" % batches_done, normalize=False) #save the ground truth of hr
            save_image(gen_hr, "images/tif_epoch200_data200_GAN0.1_ep4/gen%d.png" % batches_done, normalize=False) #save predicted results of hr
            save_image(img_grid, "images/tif_epoch200_data200_GAN0.1_ep4/%d.png" % batches_done, normalize=False) #save whole table: lr, gen_hr and hr

             #print("batch_done:%d\n" %batches_done)
  
    if checkpoint_interval != -1 and (epoch+1) % checkpoint_interval == 0:
        # Save model checkpoints
        torch.save(generator.state_dict(), "saved_models/generator_%d.pth" % epoch)
        torch.save(discriminator.state_dict(), "saved_models/discriminator_%d.pth" % epoch)
# Out:
# [Epoch 1/200] [Batch 1/25] [D loss: 0.570825] [G loss: 0.593409]
# [Epoch 1/200] [Batch 2/25] [D loss: 4.532930] [G loss: 0.404221]
# [Epoch 1/200] [Batch 3/25] [D loss: 1.421505] [G loss: 0.316859]
# [Epoch 1/200] [Batch 4/25] [D loss: 0.943829] [G loss: 0.297145]
# [Epoch 1/200] [Batch 5/25] [D loss: 0.422280] [G loss: 0.225531]
# [Epoch 1/200] [Batch 6/25] [D loss: 0.484123] [G loss: 0.192028]
# [Epoch 1/200] [Batch 7/25] [D loss: 0.281911] [G loss: 0.193787]
# [Epoch 1/200] [Batch 8/25] [D loss: 0.215377] [G loss: 0.204201]
# [Epoch 1/200] [Batch 9/25] [D loss: 0.215721] [G loss: 0.203752]
# [Epoch 1/200] [Batch 10/25] [D loss: 0.174550] [G loss: 0.231430]
# [Epoch 1/200] [Batch 11/25] [D loss: 0.184915] [G loss: 0.264256]
# [Epoch 1/200] [Batch 12/25] [D loss: 0.195023] [G loss: 0.215443]
# [Epoch 1/200] [Batch 13/25] [D loss: 0.258364] [G loss: 0.217763]
# [Epoch 1/200] [Batch 14/25] [D loss: 0.237990] [G loss: 0.285006]
# [Epoch 1/200] [Batch 15/25] [D loss: 0.149770] [G loss: 0.140373]
# [Epoch 1/200] [Batch 16/25] [D loss: 0.144921] [G loss: 0.168969]
# [Epoch 1/200] [Batch 17/25] [D loss: 0.132940] [G loss: 0.243700]
# [Epoch 1/200] [Batch 18/25] [D loss: 0.141693] [G loss: 0.209590]
# [Epoch 1/200] [Batch 19/25] [D loss: 0.142068] [G loss: 0.150954]
# [Epoch 1/200] [Batch 20/25] [D loss: 0.174406] [G loss: 0.423074]
# [Epoch 1/200] [Batch 21/25] [D loss: 0.177535] [G loss: 0.151770]
# [Epoch 1/200] [Batch 22/25] [D loss: 0.155071] [G loss: 0.213762]
# [Epoch 1/200] [Batch 23/25] [D loss: 0.173710] [G loss: 0.178941]
# [Epoch 1/200] [Batch 24/25] [D loss: 0.381765] [G loss: 0.193503]
# [Epoch 1/200] [Batch 25/25] [D loss: 0.255883] [G loss: 0.113233]
# [Epoch 2/200] [Batch 1/25] [D loss: 0.200255] [G loss: 0.215173]
# [Epoch 2/200] [Batch 2/25] [D loss: 0.189555] [G loss: 0.187872]
# [Epoch 2/200] [Batch 3/25] [D loss: 0.104444] [G loss: 0.216773]
# [Epoch 2/200] [Batch 4/25] [D loss: 0.061784] [G loss: 0.190061]
# [Epoch 2/200] [Batch 5/25] [D loss: 0.042531] [G loss: 0.119522]
# [Epoch 2/200] [Batch 6/25] [D loss: 0.174374] [G loss: 0.284839]
# [Epoch 2/200] [Batch 7/25] [D loss: 0.119165] [G loss: 0.115601]
# [Epoch 2/200] [Batch 8/25] [D loss: 0.076873] [G loss: 0.263368]
# [Epoch 2/200] [Batch 9/25] [D loss: 0.073170] [G loss: 0.108139]
# [Epoch 2/200] [Batch 10/25] [D loss: 0.074731] [G loss: 0.155814]
# [Epoch 2/200] [Batch 11/25] [D loss: 0.080654] [G loss: 0.492261]
# [Epoch 2/200] [Batch 12/25] [D loss: 0.079204] [G loss: 0.161620]
# [Epoch 2/200] [Batch 13/25] [D loss: 0.066963] [G loss: 0.178712]
# [Epoch 2/200] [Batch 14/25] [D loss: 0.110586] [G loss: 0.187308]
# [Epoch 2/200] [Batch 15/25] [D loss: 0.074652] [G loss: 0.168515]
# [Epoch 2/200] [Batch 16/25] [D loss: 0.036316] [G loss: 0.196177]
# [Epoch 2/200] [Batch 17/25] [D loss: 0.051382] [G loss: 0.264106]
# [Epoch 2/200] [Batch 18/25] [D loss: 0.063490] [G loss: 0.146489]
# [Epoch 2/200] [Batch 19/25] [D loss: 0.050495] [G loss: 0.105876]
# [Epoch 2/200] [Batch 20/25] [D loss: 0.101848] [G loss: 0.215051]
# [Epoch 2/200] [Batch 21/25] [D loss: 0.045762] [G loss: 0.163067]
# [Epoch 2/200] [Batch 22/25] [D loss: 0.033592] [G loss: 0.127825]
# [Epoch 2/200] [Batch 23/25] [D loss: 0.024361] [G loss: 0.084954]
# [Epoch 2/200] [Batch 24/25] [D loss: 0.067979] [G loss: 0.116647]
# [Epoch 2/200] [Batch 25/25] [D loss: 0.050565] [G loss: 0.203968]
# [Epoch 3/200] [Batch 1/25] [D loss: 0.053871] [G loss: 0.113276]
# [Epoch 3/200] [Batch 2/25] [D loss: 0.062072] [G loss: 0.105455]
# [Epoch 3/200] [Batch 3/25] [D loss: 0.159796] [G loss: 0.420217]
# [Epoch 3/200] [Batch 4/25] [D loss: 0.055339] [G loss: 0.070217]
# [Epoch 3/200] [Batch 5/25] [D loss: 0.046828] [G loss: 0.166685]
# [Epoch 3/200] [Batch 6/25] [D loss: 0.071227] [G loss: 0.183975]
# [Epoch 3/200] [Batch 7/25] [D loss: 0.086830] [G loss: 0.197629]
# [Epoch 3/200] [Batch 8/25] [D loss: 0.046627] [G loss: 0.130322]
# [Epoch 3/200] [Batch 9/25] [D loss: 0.039359] [G loss: 0.134354]
# [Epoch 3/200] [Batch 10/25] [D loss: 0.048458] [G loss: 0.241436]
# [Epoch 3/200] [Batch 11/25] [D loss: 0.025166] [G loss: 0.187412]
# [Epoch 3/200] [Batch 12/25] [D loss: 0.038042] [G loss: 0.191885]
# [Epoch 3/200] [Batch 13/25] [D loss: 0.027474] [G loss: 0.172693]
# [Epoch 3/200] [Batch 14/25] [D loss: 0.037090] [G loss: 0.175448]
# [Epoch 3/200] [Batch 15/25] [D loss: 0.037174] [G loss: 0.082970]
# [Epoch 3/200] [Batch 16/25] [D loss: 0.028925] [G loss: 0.077672]
# [Epoch 3/200] [Batch 17/25] [D loss: 0.063895] [G loss: 0.178266]
# [Epoch 3/200] [Batch 18/25] [D loss: 0.051401] [G loss: 0.172052]
# [Epoch 3/200] [Batch 19/25] [D loss: 0.025259] [G loss: 0.263291]
# [Epoch 3/200] [Batch 20/25] [D loss: 0.186632] [G loss: 0.257928]
# [Epoch 3/200] [Batch 21/25] [D loss: 0.175662] [G loss: 0.134266]
# [Epoch 3/200] [Batch 22/25] [D loss: 0.043186] [G loss: 0.113889]
# [Epoch 3/200] [Batch 23/25] [D loss: 0.113149] [G loss: 0.143745]
# [Epoch 3/200] [Batch 24/25] [D loss: 0.035324] [G loss: 0.147647]
# [Epoch 3/200] [Batch 25/25] [D loss: 0.024574] [G loss: 0.115674]
# [Epoch 4/200] [Batch 1/25] [D loss: 0.036995] [G loss: 0.125344]
# [Epoch 4/200] [Batch 2/25] [D loss: 0.029789] [G loss: 0.104348]
# [Epoch 4/200] [Batch 3/25] [D loss: 0.031257] [G loss: 0.380837]
# [Epoch 4/200] [Batch 4/25] [D loss: 0.105450] [G loss: 0.469821]
# [Epoch 4/200] [Batch 5/25] [D loss: 0.106372] [G loss: 0.121701]
# [Epoch 4/200] [Batch 6/25] [D loss: 0.086892] [G loss: 0.126833]
# [Epoch 4/200] [Batch 7/25] [D loss: 0.048153] [G loss: 0.224983]
# [Epoch 4/200] [Batch 8/25] [D loss: 0.037666] [G loss: 0.161977]
# [Epoch 4/200] [Batch 9/25] [D loss: 0.044648] [G loss: 0.070350]
# [Epoch 4/200] [Batch 10/25] [D loss: 0.033539] [G loss: 0.263237]
# [Epoch 4/200] [Batch 11/25] [D loss: 0.035937] [G loss: 0.232745]
# [Epoch 4/200] [Batch 12/25] [D loss: 0.025117] [G loss: 0.120749]
# [Epoch 4/200] [Batch 13/25] [D loss: 0.033297] [G loss: 0.293861]
# [Epoch 4/200] [Batch 14/25] [D loss: 0.021575] [G loss: 0.227029]
# [Epoch 4/200] [Batch 15/25] [D loss: 0.008707] [G loss: 0.111700]
# [Epoch 4/200] [Batch 16/25] [D loss: 0.013503] [G loss: 0.111730]
# [Epoch 4/200] [Batch 17/25] [D loss: 0.088158] [G loss: 0.285478]
# [Epoch 4/200] [Batch 18/25] [D loss: 0.058104] [G loss: 0.151771]
# [Epoch 4/200] [Batch 19/25] [D loss: 0.068716] [G loss: 0.180053]
# [Epoch 4/200] [Batch 20/25] [D loss: 0.101306] [G loss: 0.156274]
# [Epoch 4/200] [Batch 21/25] [D loss: 0.027381] [G loss: 0.142921]
# [Epoch 4/200] [Batch 22/25] [D loss: 0.039706] [G loss: 0.109691]
# [Epoch 4/200] [Batch 23/25] [D loss: 0.038016] [G loss: 0.158831]
# [Epoch 4/200] [Batch 24/25] [D loss: 0.036878] [G loss: 0.085597]
# [Epoch 4/200] [Batch 25/25] [D loss: 0.027520] [G loss: 0.100239]
# [Epoch 5/200] [Batch 1/25] [D loss: 0.018266] [G loss: 0.050765]
# [Epoch 5/200] [Batch 2/25] [D loss: 0.016020] [G loss: 0.081944]
# [Epoch 5/200] [Batch 3/25] [D loss: 0.022324] [G loss: 0.246667]
# [Epoch 5/200] [Batch 4/25] [D loss: 0.020351] [G loss: 0.137616]
# [Epoch 5/200] [Batch 5/25] [D loss: 0.013613] [G loss: 0.134694]
# [Epoch 5/200] [Batch 6/25] [D loss: 0.025618] [G loss: 0.134781]
# [Epoch 5/200] [Batch 7/25] [D loss: 0.014914] [G loss: 0.180216]
# [Epoch 5/200] [Batch 8/25] [D loss: 0.015011] [G loss: 0.153701]
# [Epoch 5/200] [Batch 9/25] [D loss: 0.023063] [G loss: 0.173135]
# [Epoch 5/200] [Batch 10/25] [D loss: 0.012492] [G loss: 0.165727]
# [Epoch 5/200] [Batch 11/25] [D loss: 0.015622] [G loss: 0.212797]
# [Epoch 5/200] [Batch 12/25] [D loss: 0.011313] [G loss: 0.144474]
# [Epoch 5/200] [Batch 13/25] [D loss: 0.016480] [G loss: 0.146421]
# [Epoch 5/200] [Batch 14/25] [D loss: 0.052823] [G loss: 0.181630]
# [Epoch 5/200] [Batch 15/25] [D loss: 0.046690] [G loss: 0.230145]
# [Epoch 5/200] [Batch 16/25] [D loss: 0.056659] [G loss: 0.110662]
# [Epoch 5/200] [Batch 17/25] [D loss: 0.016554] [G loss: 0.180191]
# [Epoch 5/200] [Batch 18/25] [D loss: 0.040014] [G loss: 0.159595]
# [Epoch 5/200] [Batch 19/25] [D loss: 0.031996] [G loss: 0.136938]
# [Epoch 5/200] [Batch 20/25] [D loss: 0.010795] [G loss: 0.073994]
# [Epoch 5/200] [Batch 21/25] [D loss: 0.029070] [G loss: 0.327264]
# [Epoch 5/200] [Batch 22/25] [D loss: 0.064980] [G loss: 0.145782]
# [Epoch 5/200] [Batch 23/25] [D loss: 0.091285] [G loss: 0.137210]
# [Epoch 5/200] [Batch 24/25] [D loss: 0.035895] [G loss: 0.145010]
# [Epoch 5/200] [Batch 25/25] [D loss: 0.037446] [G loss: 0.124685]
# [Epoch 6/200] [Batch 1/25] [D loss: 0.036376] [G loss: 0.098883]
# [Epoch 6/200] [Batch 2/25] [D loss: 0.080799] [G loss: 0.268105]
# [Epoch 6/200] [Batch 3/25] [D loss: 0.058019] [G loss: 0.157922]
# [Epoch 6/200] [Batch 4/25] [D loss: 0.029420] [G loss: 0.251772]
# [Epoch 6/200] [Batch 5/25] [D loss: 0.013672] [G loss: 0.213434]
# [Epoch 6/200] [Batch 6/25] [D loss: 0.013786] [G loss: 0.101010]
# [Epoch 6/200] [Batch 7/25] [D loss: 0.038311] [G loss: 0.413316]
# [Epoch 6/200] [Batch 8/25] [D loss: 0.037491] [G loss: 0.072722]
# [Epoch 6/200] [Batch 9/25] [D loss: 0.029779] [G loss: 0.232122]
# [Epoch 6/200] [Batch 10/25] [D loss: 0.028286] [G loss: 0.212023]
# [Epoch 6/200] [Batch 11/25] [D loss: 0.022723] [G loss: 0.187044]
# [Epoch 6/200] [Batch 12/25] [D loss: 0.021375] [G loss: 0.162900]
# [Epoch 6/200] [Batch 13/25] [D loss: 0.015537] [G loss: 0.143379]
# [Epoch 6/200] [Batch 14/25] [D loss: 0.009914] [G loss: 0.096159]
# [Epoch 6/200] [Batch 15/25] [D loss: 0.005560] [G loss: 0.100735]
# [Epoch 6/200] [Batch 16/25] [D loss: 0.012626] [G loss: 0.068673]
# [Epoch 6/200] [Batch 17/25] [D loss: 0.009596] [G loss: 0.081792]
# [Epoch 6/200] [Batch 18/25] [D loss: 0.009944] [G loss: 0.273337]
# [Epoch 6/200] [Batch 19/25] [D loss: 0.006694] [G loss: 0.102729]
# [Epoch 6/200] [Batch 20/25] [D loss: 0.010017] [G loss: 0.104915]
# [Epoch 6/200] [Batch 21/25] [D loss: 0.011816] [G loss: 0.109718]
# [Epoch 6/200] [Batch 22/25] [D loss: 0.010061] [G loss: 0.177842]
# [Epoch 6/200] [Batch 23/25] [D loss: 0.020113] [G loss: 0.216658]
# [Epoch 6/200] [Batch 24/25] [D loss: 0.015408] [G loss: 0.204021]
# [Epoch 6/200] [Batch 25/25] [D loss: 0.008388] [G loss: 0.145258]
# [Epoch 7/200] [Batch 1/25] [D loss: 0.025067] [G loss: 0.125302]
# [Epoch 7/200] [Batch 2/25] [D loss: 0.013864] [G loss: 0.159380]
# [Epoch 7/200] [Batch 3/25] [D loss: 0.020088] [G loss: 0.263347]
# [Epoch 7/200] [Batch 4/25] [D loss: 0.035250] [G loss: 0.133542]
# [Epoch 7/200] [Batch 5/25] [D loss: 0.014800] [G loss: 0.214717]
# [Epoch 7/200] [Batch 6/25] [D loss: 0.046494] [G loss: 0.376551]
# [Epoch 7/200] [Batch 7/25] [D loss: 0.038161] [G loss: 0.157708]
# [Epoch 7/200] [Batch 8/25] [D loss: 0.031541] [G loss: 0.113722]
# [Epoch 7/200] [Batch 9/25] [D loss: 0.027995] [G loss: 0.147845]
# [Epoch 7/200] [Batch 10/25] [D loss: 0.044619] [G loss: 0.283727]
# [Epoch 7/200] [Batch 11/25] [D loss: 0.043769] [G loss: 0.125464]
# [Epoch 7/200] [Batch 12/25] [D loss: 0.040968] [G loss: 0.174507]
# [Epoch 7/200] [Batch 13/25] [D loss: 0.029441] [G loss: 0.112385]
# [Epoch 7/200] [Batch 14/25] [D loss: 0.079158] [G loss: 0.076847]
# [Epoch 7/200] [Batch 15/25] [D loss: 0.486637] [G loss: 0.148381]
# [Epoch 7/200] [Batch 16/25] [D loss: 0.073571] [G loss: 0.131386]
# [Epoch 7/200] [Batch 17/25] [D loss: 0.123266] [G loss: 0.104373]
# [Epoch 7/200] [Batch 18/25] [D loss: 0.058964] [G loss: 0.075183]
# [Epoch 7/200] [Batch 19/25] [D loss: 0.066610] [G loss: 0.180377]
# [Epoch 7/200] [Batch 20/25] [D loss: 0.021866] [G loss: 0.134074]
# [Epoch 7/200] [Batch 21/25] [D loss: 0.051587] [G loss: 0.234019]
# [Epoch 7/200] [Batch 22/25] [D loss: 0.018573] [G loss: 0.187245]
# [Epoch 7/200] [Batch 23/25] [D loss: 0.022488] [G loss: 0.163562]
# [Epoch 7/200] [Batch 24/25] [D loss: 0.028784] [G loss: 0.104257]
# [Epoch 7/200] [Batch 25/25] [D loss: 0.018184] [G loss: 0.063337]
# [Epoch 8/200] [Batch 1/25] [D loss: 0.038116] [G loss: 0.403200]
# [Epoch 8/200] [Batch 2/25] [D loss: 0.043158] [G loss: 0.114606]
# [Epoch 8/200] [Batch 3/25] [D loss: 0.032747] [G loss: 0.089002]
# [Epoch 8/200] [Batch 4/25] [D loss: 0.018193] [G loss: 0.127369]
# [Epoch 8/200] [Batch 5/25] [D loss: 0.023955] [G loss: 0.063100]
# [Epoch 8/200] [Batch 6/25] [D loss: 0.048648] [G loss: 0.263306]
# [Epoch 8/200] [Batch 7/25] [D loss: 0.070503] [G loss: 0.072843]
# [Epoch 8/200] [Batch 8/25] [D loss: 0.025606] [G loss: 0.106466]
# [Epoch 8/200] [Batch 9/25] [D loss: 0.028049] [G loss: 0.135522]
# [Epoch 8/200] [Batch 10/25] [D loss: 0.045683] [G loss: 0.250392]
# [Epoch 8/200] [Batch 11/25] [D loss: 0.044188] [G loss: 0.294549]
# [Epoch 8/200] [Batch 12/25] [D loss: 0.025472] [G loss: 0.145451]
# [Epoch 8/200] [Batch 13/25] [D loss: 0.028846] [G loss: 0.121298]
# [Epoch 8/200] [Batch 14/25] [D loss: 0.028607] [G loss: 0.118932]
# [Epoch 8/200] [Batch 15/25] [D loss: 0.013212] [G loss: 0.105222]
# [Epoch 8/200] [Batch 16/25] [D loss: 0.008197] [G loss: 0.100785]
# [Epoch 8/200] [Batch 17/25] [D loss: 0.014287] [G loss: 0.217704]
# [Epoch 8/200] [Batch 18/25] [D loss: 0.048298] [G loss: 0.118790]
# [Epoch 8/200] [Batch 19/25] [D loss: 0.034138] [G loss: 0.241639]
# [Epoch 8/200] [Batch 20/25] [D loss: 0.014631] [G loss: 0.121346]
# [Epoch 8/200] [Batch 21/25] [D loss: 0.023931] [G loss: 0.158574]
# [Epoch 8/200] [Batch 22/25] [D loss: 0.014044] [G loss: 0.083338]
# [Epoch 8/200] [Batch 23/25] [D loss: 0.013053] [G loss: 0.114524]
# [Epoch 8/200] [Batch 24/25] [D loss: 0.010944] [G loss: 0.142308]
# [Epoch 8/200] [Batch 25/25] [D loss: 0.009730] [G loss: 0.135183]
# [Epoch 9/200] [Batch 1/25] [D loss: 0.013685] [G loss: 0.128057]
# [Epoch 9/200] [Batch 2/25] [D loss: 0.012700] [G loss: 0.176721]
# [Epoch 9/200] [Batch 3/25] [D loss: 0.016172] [G loss: 0.130919]
# [Epoch 9/200] [Batch 4/25] [D loss: 0.010823] [G loss: 0.119192]
# [Epoch 9/200] [Batch 5/25] [D loss: 0.006653] [G loss: 0.105758]
# [Epoch 9/200] [Batch 6/25] [D loss: 0.006499] [G loss: 0.068858]
# [Epoch 9/200] [Batch 7/25] [D loss: 0.004555] [G loss: 0.086505]
# [Epoch 9/200] [Batch 8/25] [D loss: 0.005155] [G loss: 0.131522]
# [Epoch 9/200] [Batch 9/25] [D loss: 0.007626] [G loss: 0.078133]
# [Epoch 9/200] [Batch 10/25] [D loss: 0.009091] [G loss: 0.089395]
# [Epoch 9/200] [Batch 11/25] [D loss: 0.009620] [G loss: 0.114314]
# [Epoch 9/200] [Batch 12/25] [D loss: 0.015724] [G loss: 0.140082]
# [Epoch 9/200] [Batch 13/25] [D loss: 0.015519] [G loss: 0.078928]
# [Epoch 9/200] [Batch 14/25] [D loss: 0.013916] [G loss: 0.104811]
# [Epoch 9/200] [Batch 15/25] [D loss: 0.046301] [G loss: 0.241898]
# [Epoch 9/200] [Batch 16/25] [D loss: 0.282737] [G loss: 0.091570]
# [Epoch 9/200] [Batch 17/25] [D loss: 0.368850] [G loss: 0.110965]
# [Epoch 9/200] [Batch 18/25] [D loss: 0.071181] [G loss: 0.122373]
# [Epoch 9/200] [Batch 19/25] [D loss: 0.167464] [G loss: 0.109766]
# [Epoch 9/200] [Batch 20/25] [D loss: 0.021607] [G loss: 0.071723]
# [Epoch 9/200] [Batch 21/25] [D loss: 0.138182] [G loss: 0.258023]
# [Epoch 9/200] [Batch 22/25] [D loss: 0.144025] [G loss: 0.193549]
# [Epoch 9/200] [Batch 23/25] [D loss: 0.069299] [G loss: 0.125585]
# [Epoch 9/200] [Batch 24/25] [D loss: 0.079006] [G loss: 0.206333]
# [Epoch 9/200] [Batch 25/25] [D loss: 0.099139] [G loss: 0.136474]
# [Epoch 10/200] [Batch 1/25] [D loss: 0.237420] [G loss: 0.097687]
# [Epoch 10/200] [Batch 2/25] [D loss: 0.128734] [G loss: 0.177054]
# [Epoch 10/200] [Batch 3/25] [D loss: 0.301899] [G loss: 0.074508]
# [Epoch 10/200] [Batch 4/25] [D loss: 0.492637] [G loss: 0.163636]
# [Epoch 10/200] [Batch 5/25] [D loss: 0.352442] [G loss: 0.142515]
# [Epoch 10/200] [Batch 6/25] [D loss: 0.195135] [G loss: 0.132578]
# [Epoch 10/200] [Batch 7/25] [D loss: 0.149365] [G loss: 0.058315]
# [Epoch 10/200] [Batch 8/25] [D loss: 0.074121] [G loss: 0.131472]
# [Epoch 10/200] [Batch 9/25] [D loss: 0.061184] [G loss: 0.137284]
# [Epoch 10/200] [Batch 10/25] [D loss: 0.029386] [G loss: 0.104074]
# [Epoch 10/200] [Batch 11/25] [D loss: 0.072663] [G loss: 0.102579]
# [Epoch 10/200] [Batch 12/25] [D loss: 0.035790] [G loss: 0.099367]
# [Epoch 10/200] [Batch 13/25] [D loss: 0.029662] [G loss: 0.080236]
# [Epoch 10/200] [Batch 14/25] [D loss: 0.018662] [G loss: 0.072384]
# [Epoch 10/200] [Batch 15/25] [D loss: 0.024067] [G loss: 0.096786]
# [Epoch 10/200] [Batch 16/25] [D loss: 0.187412] [G loss: 0.371396]
# [Epoch 10/200] [Batch 17/25] [D loss: 0.428269] [G loss: 0.215917]
# [Epoch 10/200] [Batch 18/25] [D loss: 0.035900] [G loss: 0.073965]
# [Epoch 10/200] [Batch 19/25] [D loss: 0.048235] [G loss: 0.223380]
# [Epoch 10/200] [Batch 20/25] [D loss: 0.025294] [G loss: 0.152611]
# [Epoch 10/200] [Batch 21/25] [D loss: 0.027454] [G loss: 0.148908]
# [Epoch 10/200] [Batch 22/25] [D loss: 0.021529] [G loss: 0.047946]
# [Epoch 10/200] [Batch 23/25] [D loss: 0.025245] [G loss: 0.054394]
# [Epoch 10/200] [Batch 24/25] [D loss: 0.038369] [G loss: 0.287879]
# [Epoch 10/200] [Batch 25/25] [D loss: 0.034349] [G loss: 0.043355]
# [Epoch 11/200] [Batch 1/25] [D loss: 0.020539] [G loss: 0.100130]
# [Epoch 11/200] [Batch 2/25] [D loss: 0.021725] [G loss: 0.049829]
# [Epoch 11/200] [Batch 3/25] [D loss: 0.019445] [G loss: 0.099370]
# [Epoch 11/200] [Batch 4/25] [D loss: 0.025917] [G loss: 0.111012]
# [Epoch 11/200] [Batch 5/25] [D loss: 0.015605] [G loss: 0.144717]
# [Epoch 11/200] [Batch 6/25] [D loss: 0.019678] [G loss: 0.089887]
# [Epoch 11/200] [Batch 7/25] [D loss: 0.015095] [G loss: 0.071581]
# [Epoch 11/200] [Batch 8/25] [D loss: 0.010455] [G loss: 0.055719]
# [Epoch 11/200] [Batch 9/25] [D loss: 0.009283] [G loss: 0.058720]
# [Epoch 11/200] [Batch 10/25] [D loss: 0.007554] [G loss: 0.077714]
# [Epoch 11/200] [Batch 11/25] [D loss: 0.031299] [G loss: 0.177370]
# [Epoch 11/200] [Batch 12/25] [D loss: 0.018180] [G loss: 0.101342]
# [Epoch 11/200] [Batch 13/25] [D loss: 0.018394] [G loss: 0.199403]
# [Epoch 11/200] [Batch 14/25] [D loss: 0.026836] [G loss: 0.060904]
# [Epoch 11/200] [Batch 15/25] [D loss: 0.009710] [G loss: 0.084999]
# [Epoch 11/200] [Batch 16/25] [D loss: 0.015559] [G loss: 0.225870]
# [Epoch 11/200] [Batch 17/25] [D loss: 0.025790] [G loss: 0.096578]
# [Epoch 11/200] [Batch 18/25] [D loss: 0.030582] [G loss: 0.229103]
# [Epoch 11/200] [Batch 19/25] [D loss: 0.023246] [G loss: 0.105683]
# [Epoch 11/200] [Batch 20/25] [D loss: 0.010732] [G loss: 0.079774]
# [Epoch 11/200] [Batch 21/25] [D loss: 0.007302] [G loss: 0.061946]
# [Epoch 11/200] [Batch 22/25] [D loss: 0.009088] [G loss: 0.194902]
# [Epoch 11/200] [Batch 23/25] [D loss: 0.007364] [G loss: 0.156239]
# [Epoch 11/200] [Batch 24/25] [D loss: 0.005406] [G loss: 0.046363]
# [Epoch 11/200] [Batch 25/25] [D loss: 0.006447] [G loss: 0.098231]
# [Epoch 12/200] [Batch 1/25] [D loss: 0.006222] [G loss: 0.103313]
# [Epoch 12/200] [Batch 2/25] [D loss: 0.005854] [G loss: 0.081764]
# [Epoch 12/200] [Batch 3/25] [D loss: 0.004221] [G loss: 0.055990]
# [Epoch 12/200] [Batch 4/25] [D loss: 0.005942] [G loss: 0.135169]
# [Epoch 12/200] [Batch 5/25] [D loss: 0.020408] [G loss: 0.344552]
# [Epoch 12/200] [Batch 6/25] [D loss: 0.029043] [G loss: 0.111933]
# [Epoch 12/200] [Batch 7/25] [D loss: 0.010612] [G loss: 0.075501]
# [Epoch 12/200] [Batch 8/25] [D loss: 0.008725] [G loss: 0.089908]
# [Epoch 12/200] [Batch 9/25] [D loss: 0.017360] [G loss: 0.152840]
# [Epoch 12/200] [Batch 10/25] [D loss: 0.006901] [G loss: 0.063120]
# [Epoch 12/200] [Batch 11/25] [D loss: 0.016051] [G loss: 0.151333]
# [Epoch 12/200] [Batch 12/25] [D loss: 0.014655] [G loss: 0.048171]
# [Epoch 12/200] [Batch 13/25] [D loss: 0.007628] [G loss: 0.109011]
# [Epoch 12/200] [Batch 14/25] [D loss: 0.007081] [G loss: 0.082045]
# [Epoch 12/200] [Batch 15/25] [D loss: 0.011694] [G loss: 0.141866]
# [Epoch 12/200] [Batch 16/25] [D loss: 0.007144] [G loss: 0.124123]
# [Epoch 12/200] [Batch 17/25] [D loss: 0.006228] [G loss: 0.102750]
# [Epoch 12/200] [Batch 18/25] [D loss: 0.010128] [G loss: 0.155138]
# [Epoch 12/200] [Batch 19/25] [D loss: 0.011544] [G loss: 0.051014]
# [Epoch 12/200] [Batch 20/25] [D loss: 0.005927] [G loss: 0.104355]
# [Epoch 12/200] [Batch 21/25] [D loss: 0.007690] [G loss: 0.079434]
# [Epoch 12/200] [Batch 22/25] [D loss: 0.004151] [G loss: 0.053129]
# [Epoch 12/200] [Batch 23/25] [D loss: 0.006791] [G loss: 0.124622]
# [Epoch 12/200] [Batch 24/25] [D loss: 0.009747] [G loss: 0.104205]
# [Epoch 12/200] [Batch 25/25] [D loss: 0.004482] [G loss: 0.053807]
# [Epoch 13/200] [Batch 1/25] [D loss: 0.012248] [G loss: 0.076103]
# [Epoch 13/200] [Batch 2/25] [D loss: 0.016871] [G loss: 0.135197]
# [Epoch 13/200] [Batch 3/25] [D loss: 0.012072] [G loss: 0.112665]
# [Epoch 13/200] [Batch 4/25] [D loss: 0.005646] [G loss: 0.045931]
# [Epoch 13/200] [Batch 5/25] [D loss: 0.009849] [G loss: 0.146702]
# [Epoch 13/200] [Batch 6/25] [D loss: 0.007966] [G loss: 0.181181]
# [Epoch 13/200] [Batch 7/25] [D loss: 0.012435] [G loss: 0.122775]
# [Epoch 13/200] [Batch 8/25] [D loss: 0.004453] [G loss: 0.061160]
# [Epoch 13/200] [Batch 9/25] [D loss: 0.005041] [G loss: 0.101919]
# [Epoch 13/200] [Batch 10/25] [D loss: 0.002761] [G loss: 0.028593]
# [Epoch 13/200] [Batch 11/25] [D loss: 0.004093] [G loss: 0.112243]
# [Epoch 13/200] [Batch 12/25] [D loss: 0.006757] [G loss: 0.039446]
# [Epoch 13/200] [Batch 13/25] [D loss: 0.003001] [G loss: 0.091897]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_23503/308224641.py in <module>
#     106
#     107         # Generate a high resolution image from low resolution input
# --> 108         gen_hr = generator(imgs_lr)
#     109         #print(gen_hr)
#     110
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/PyTorch-GAN/implementations/srgan/models.py in forward(self, x)
#      64     def forward(self, x):
#      65         out1 = self.conv1(x)
# ---> 66         out = self.res_blocks(out1)
#      67         out2 = self.conv2(out)
#      68         out = torch.add(out1, out2)
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/PyTorch-GAN/implementations/srgan/models.py in forward(self, x)
#      28
#      29     def forward(self, x):
# ---> 30         return x + self.conv_block(x)
#      31
#      32
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot
#np.save('Loss/Dloss8.npy',Dloss)
np.save('Loss/4_Jan10.npy',Gloss)
#pyplot.plot(Dloss, label='Discriminator')

pyplot.figure(figsize=(16,9))
pyplot.plot(Gloss, label='Generator')
pyplot.legend()
pyplot.savefig('3_Jan10.png') 
pyplot.show()

# %%
#print the images for the last batch
#three columns: imgs_lr, gen_hr, imgs_hr

import matplotlib.pyplot as plt
fig, axes=plt.subplots(1,1,figsize=(9,15))
axes.imshow(img_grid.cpu().numpy()[0], cmap='gray')

# %%
import cv2
from math import log10, sqrt
# Test loss   

def PSNR(original, generator):
    mse = np.mean((original - generator) ** 2)
    if(mse == 0): # MSE is zero means no noise is present in the signal .
                # Therefore PSNR have no importance.
        return 100
    max_pixel = 255
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr
    
img_hr = 'images/hr'+str(batches_done)+'.png'
img_gen = 'images/gen'+str(batches_done)+'.png'
original = cv2.imread(img_hr)
generator = cv2.imread(img_gen)
value = PSNR(original, generator) 
value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5925/3948431835.py in <module>
#      16 original = cv2.imread(img_hr)
#      17 generator = cv2.imread(img_gen)
# ---> 18 value = PSNR(original, generator)
#      19 value
#
# /tmp/ipykernel_5925/3948431835.py in PSNR(original, generator)
#       4
#       5 def PSNR(original, generator):
# ----> 6     mse = np.mean((original - generator) ** 2)
#       7     if(mse == 0): # MSE is zero means no noise is present in the signal .
#       8                 # Therefore PSNR have no importance.
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'NoneType'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error

img_hr = 'images/hr'+str(batches_done)+'.png'
img_gen = 'images/gen'+str(batches_done)+'.png'

imgs_hr = cv2.imread(img_hr,0)
img = imgs_hr
rows, cols = img.shape

gen_hr = cv2.imread(img_gen,0)
img_noise = gen_hr

mse_none = mean_squared_error(img, img)
ssim_none = ssim(img, img, data_range=img.max() - img.min())

mse_noise = mean_squared_error(img, img_noise)
ssim_noise = ssim(img, img_noise, data_range = img_noise.max() - img_noise.min())

print('SSIM of the original image: %d, SSIM of the generated image: %f'%(ssim_none,ssim_noise))
# fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4),
#                          sharex=True, sharey=True)
# ax = axes.ravel()

# ax[0].imshow(img, cmap=plt.cm.gray, vmin=0, vmax=1)
# ax[0].set_xlabel(f'MSE: {mse_none:.2f}, SSIM: {ssim_none:.2f}')
# ax[0].set_title('Original image')

# ax[1].imshow(img_noise, cmap=plt.cm.gray, vmin=0, vmax=1)
# ax[1].set_xlabel(f'MSE: {mse_noise:.2f}, SSIM: {ssim_noise:.2f}')
# ax[1].set_title('Image with noise')

# plt.tight_layout()
# plt.show()
# Out:
# SSIM of the original image: 1, SSIM of the generated image: 0.880238
